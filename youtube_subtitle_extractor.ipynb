# %%
import os
import re
from googleapiclient.discovery import build
from datetime import timedelta
 # Installs the yt-dlp package.
import yt_dlp


API_KEY = "AIzaSyBtRMQnNQ3XwlCbS1i4td5r3qDd40WeA10"
CHANNEL_ID = "UC_HK0fs_YyxhvkkiPoL_w6A"

# Initialize YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to get video IDs from a YouTube channel
def get_video_ids(channel_id):
    video_ids = []
    next_page_token = None

    while True:
        # Fetch playlist items (uploads)
        response = youtube.search().list(
            part="id",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token,
            type="video"
        ).execute()

        # Collect video IDs
        for item in response.get("items", []):
            video_ids.append(item["id"]["videoId"])

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return video_ids

# Function to convert ISO 8601 duration to seconds
def parse_duration(duration):
    match = re.match(
        r"PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?",
        duration
    )
    if not match:
        return 0

    hours, minutes, seconds = match.groups()
    delta = timedelta(
        hours=int(hours) if hours else 0,
        minutes=int(minutes) if minutes else 0,
        seconds=int(seconds) if seconds else 0,
    )
    return int(delta.total_seconds())

# Function to filter videos longer than 5 minutes
def get_video_durations(video_ids):
    long_videos = []
    for i in range(0, len(video_ids), 50):
        # Fetch video details
        response = youtube.videos().list(
            part="contentDetails",
            id=",".join(video_ids[i:i+50])
        ).execute()

        for item in response["items"]:
            duration = item["contentDetails"]["duration"]

            # Convert ISO 8601 duration to seconds
            seconds = parse_duration(duration)
            if seconds > 300:  # 300 seconds = 5 minutes
                long_videos.append(f"https://www.youtube.com/watch?v={item['id']}")

    return long_videos

# Function to download subtitles
def download_subtitles(video_urls, download_folder):
    os.makedirs(download_folder, exist_ok=True)

    # Create yt-dlp options for subtitles
    ydl_opts = {
        'writeautomaticsub': True,  # Download auto-generated subtitles if available
        'writesubtitles': True,     # Download subtitles if available
        'subtitleslangs': ['en'],   # Download subtitles in English
        'skip_download': True,      # Skip the video download, only download subtitles
        'outtmpl': f'{download_folder}/%(id)s.%(ext)s'  # Save subtitles with video ID as filename
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        for url in video_urls:
            try:
                print(f"Downloading subtitles for {url}...")
                ydl.download([url])
            except Exception as e:
                print(f"Error downloading subtitles for {url}: {e}")

# Main flow
def main():
    # Get video IDs from the channel
    video_ids = get_video_ids(CHANNEL_ID)
    print(f"Found {len(video_ids)} videos on the channel.")

    # Filter out videos longer than 5 minutes
    long_videos = get_video_durations(video_ids)
    print(f"Found {len(long_videos)} videos longer than 5 minutes.")

    # Specify the folder to save subtitles locally
    download_folder = "/content/drive/MyDrive/Downloads/subtitles"

    # Download subtitles for videos longer than 5 minutes
    download_subtitles(long_videos, download_folder)
    print(f"Subtitles downloaded to {download_folder}")

# Run the script
main()
# Out:
# Found 12 videos on the channel.
# Found 12 videos longer than 5 minutes.
# Downloading subtitles for https://www.youtube.com/watch?v=NJAmQoYH75U...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NJAmQoYH75U
# [youtube] NJAmQoYH75U: Downloading webpage
# [youtube] NJAmQoYH75U: Downloading ios player API JSON
# [youtube] NJAmQoYH75U: Downloading mweb player API JSON
# [youtube] NJAmQoYH75U: Downloading m3u8 information
# [info] NJAmQoYH75U: Downloading subtitles: en
# [info] NJAmQoYH75U: Downloading 1 format(s): 244+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/NJAmQoYH75U.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/NJAmQoYH75U.en.vtt
# [download] 100% of  442.23KiB in 00:00:00 at 2.46MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=3ORZlDTesng...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3ORZlDTesng
# [youtube] 3ORZlDTesng: Downloading webpage
# [youtube] 3ORZlDTesng: Downloading ios player API JSON
# [youtube] 3ORZlDTesng: Downloading mweb player API JSON
# [youtube] 3ORZlDTesng: Downloading player 03dbdfab
# [youtube] 3ORZlDTesng: Downloading m3u8 information
# [info] 3ORZlDTesng: Downloading subtitles: en
# [info] 3ORZlDTesng: Downloading 1 format(s): 135+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/3ORZlDTesng.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/3ORZlDTesng.en.vtt
# [download] 100% of  407.96KiB in 00:00:00 at 2.34MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=BKWO-iDR5Mc...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BKWO-iDR5Mc
# [youtube] BKWO-iDR5Mc: Downloading webpage
# [youtube] BKWO-iDR5Mc: Downloading ios player API JSON
# [youtube] BKWO-iDR5Mc: Downloading mweb player API JSON
# [youtube] BKWO-iDR5Mc: Downloading m3u8 information
# [info] BKWO-iDR5Mc: Downloading subtitles: en
# [info] BKWO-iDR5Mc: Downloading 1 format(s): 243+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/BKWO-iDR5Mc.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/BKWO-iDR5Mc.en.vtt
# [download] 100% of  428.57KiB in 00:00:00 at 2.24MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=s0cl_TzM5cY...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=s0cl_TzM5cY
# [youtube] s0cl_TzM5cY: Downloading webpage
# [youtube] s0cl_TzM5cY: Downloading ios player API JSON
# [youtube] s0cl_TzM5cY: Downloading mweb player API JSON
# [youtube] s0cl_TzM5cY: Downloading m3u8 information
# [info] s0cl_TzM5cY: Downloading subtitles: en
# [info] s0cl_TzM5cY: Downloading 1 format(s): 243+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/s0cl_TzM5cY.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/s0cl_TzM5cY.en.vtt
# [download] 100% of  415.38KiB in 00:00:00 at 2.43MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=h9bjY9k-lE4...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=h9bjY9k-lE4
# [youtube] h9bjY9k-lE4: Downloading webpage
# [youtube] h9bjY9k-lE4: Downloading ios player API JSON
# [youtube] h9bjY9k-lE4: Downloading mweb player API JSON
# [youtube] h9bjY9k-lE4: Downloading m3u8 information
# [info] h9bjY9k-lE4: Downloading subtitles: en
# [info] h9bjY9k-lE4: Downloading 1 format(s): 135+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/h9bjY9k-lE4.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/h9bjY9k-lE4.en.vtt
# [download] 100% of  449.36KiB in 00:00:00 at 2.57MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=UKAoz_MwBYQ...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UKAoz_MwBYQ
# [youtube] UKAoz_MwBYQ: Downloading webpage
# [youtube] UKAoz_MwBYQ: Downloading ios player API JSON
# [youtube] UKAoz_MwBYQ: Downloading mweb player API JSON
# [youtube] UKAoz_MwBYQ: Downloading m3u8 information
# [info] UKAoz_MwBYQ: Downloading subtitles: en
# [info] UKAoz_MwBYQ: Downloading 1 format(s): 136+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/UKAoz_MwBYQ.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/UKAoz_MwBYQ.en.vtt
# [download] 100% of  451.48KiB in 00:00:00 at 2.94MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=mBwd-sB56IY...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mBwd-sB56IY
# [youtube] mBwd-sB56IY: Downloading webpage
# [youtube] mBwd-sB56IY: Downloading ios player API JSON
# [youtube] mBwd-sB56IY: Downloading mweb player API JSON
# [youtube] mBwd-sB56IY: Downloading m3u8 information
# [info] mBwd-sB56IY: Downloading subtitles: en
# [info] mBwd-sB56IY: Downloading 1 format(s): 243+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/mBwd-sB56IY.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/mBwd-sB56IY.en.vtt
# [download] 100% of  454.87KiB in 00:00:00 at 2.14MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=T8fWi6MTRP0...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T8fWi6MTRP0
# [youtube] T8fWi6MTRP0: Downloading webpage
# [youtube] T8fWi6MTRP0: Downloading ios player API JSON
# [youtube] T8fWi6MTRP0: Downloading mweb player API JSON
# [youtube] T8fWi6MTRP0: Downloading m3u8 information
# [info] T8fWi6MTRP0: Downloading subtitles: en
# [info] T8fWi6MTRP0: Downloading 1 format(s): 136+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/T8fWi6MTRP0.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/T8fWi6MTRP0.en.vtt
# [download] 100% of  449.83KiB in 00:00:00 at 2.73MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=YxhErM1jl4g...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YxhErM1jl4g
# [youtube] YxhErM1jl4g: Downloading webpage
# [youtube] YxhErM1jl4g: Downloading ios player API JSON
# [youtube] YxhErM1jl4g: Downloading mweb player API JSON
# [youtube] YxhErM1jl4g: Downloading m3u8 information
# [info] YxhErM1jl4g: Downloading subtitles: en
# [info] YxhErM1jl4g: Downloading 1 format(s): 136+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/YxhErM1jl4g.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/YxhErM1jl4g.en.vtt
# [download] 100% of  432.57KiB in 00:00:00 at 2.39MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=yBVIwNCudY8...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yBVIwNCudY8
# [youtube] yBVIwNCudY8: Downloading webpage
# [youtube] yBVIwNCudY8: Downloading ios player API JSON
# [youtube] yBVIwNCudY8: Downloading mweb player API JSON
# [youtube] yBVIwNCudY8: Downloading m3u8 information
# [info] yBVIwNCudY8: Downloading subtitles: en
# [info] yBVIwNCudY8: Downloading 1 format(s): 243+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/yBVIwNCudY8.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/yBVIwNCudY8.en.vtt
# [download] 100% of  445.66KiB in 00:00:00 at 2.68MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=mL7aKj4114k...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mL7aKj4114k
# [youtube] mL7aKj4114k: Downloading webpage
# [youtube] mL7aKj4114k: Downloading ios player API JSON
# [youtube] mL7aKj4114k: Downloading mweb player API JSON
# [youtube] mL7aKj4114k: Downloading m3u8 information
# [info] mL7aKj4114k: Downloading subtitles: en
# [info] mL7aKj4114k: Downloading 1 format(s): 135+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/mL7aKj4114k.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/mL7aKj4114k.en.vtt
# [download] 100% of  408.07KiB in 00:00:00 at 2.22MiB/s
# Downloading subtitles for https://www.youtube.com/watch?v=aM_f_Ko7ntg...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aM_f_Ko7ntg
# [youtube] aM_f_Ko7ntg: Downloading webpage
# [youtube] aM_f_Ko7ntg: Downloading ios player API JSON
# [youtube] aM_f_Ko7ntg: Downloading mweb player API JSON
# [youtube] aM_f_Ko7ntg: Downloading m3u8 information
# [info] aM_f_Ko7ntg: Downloading subtitles: en
# [info] aM_f_Ko7ntg: Downloading 1 format(s): 243+251
# [info] Writing video subtitles to: /content/drive/MyDrive/Downloads/subtitles/aM_f_Ko7ntg.en.vtt
# [download] Destination: /content/drive/MyDrive/Downloads/subtitles/aM_f_Ko7ntg.en.vtt
# [download] 100% of  463.17KiB in 00:00:00 at 2.43MiB/s
# Subtitles downloaded to /content/drive/MyDrive/Downloads/subtitles

# %%
import os

# Directory where .vtt files are saved
vtt_folder = "/content/drive/MyDrive/Downloads/subtitles"
# New folder to store .txt files
txt_folder = "/content/drive/MyDrive/Downloads/text_subtitles"
os.makedirs(txt_folder, exist_ok=True)

# Function to convert .vtt to .txt
def convert_vtt_to_txt(vtt_folder, txt_folder):
    # Iterate over all .vtt files in the vtt_folder
    for filename in os.listdir(vtt_folder):
        if filename.endswith(".vtt"):
            vtt_path = os.path.join(vtt_folder, filename)

            # Read the .vtt file content
            with open(vtt_path, "r", encoding="utf-8") as file:
                lines = file.readlines()

            # Extract subtitle text (ignoring timestamps and metadata)
            subtitle_text = []
            for line in lines:
                if "-->" not in line:  # Ignore timestamps
                    subtitle_text.append(line.strip())

            # Combine all text and save to a .txt file
            txt_filename = filename.replace(".vtt", ".txt")
            txt_path = os.path.join(txt_folder, txt_filename)

            with open(txt_path, "w", encoding="utf-8") as file:
                file.write("\n".join(subtitle_text))

            print(f"Converted {filename} to {txt_filename}")

# Run the conversion
convert_vtt_to_txt(vtt_folder, txt_folder)
print(f"Subtitles converted to text and saved in {txt_folder}")
# Out:
# Converted RnZbCnf6MMw.en.vtt to RnZbCnf6MMw.en.txt
# Converted OOYljgw7P6M.en.vtt to OOYljgw7P6M.en.txt
# Converted LRLGVq9OGHs.en.vtt to LRLGVq9OGHs.en.txt
# Converted 8FhLkwvSHkA.en.vtt to 8FhLkwvSHkA.en.txt
# Converted vnvQAqzcBAM.en.vtt to vnvQAqzcBAM.en.txt
# Converted _UQeqPRyup0.en.vtt to _UQeqPRyup0.en.txt
# Converted wSi9F00yfBc.en.vtt to wSi9F00yfBc.en.txt
# Converted JGxLVCHiMGs.en.vtt to JGxLVCHiMGs.en.txt
# Converted ysaZw1EPWx8.en.vtt to ysaZw1EPWx8.en.txt
# Converted H3sB3SGj-5o.en.vtt to H3sB3SGj-5o.en.txt
# Converted TbvgVnFR_tY.en.vtt to TbvgVnFR_tY.en.txt
# Converted KMTtzM_n8Cg.en.vtt to KMTtzM_n8Cg.en.txt
# Converted pVhVrP6ceko.en.vtt to pVhVrP6ceko.en.txt
# Converted tleuOOLhyH8.en.vtt to tleuOOLhyH8.en.txt
# Converted YNbY9Juix6g.en.vtt to YNbY9Juix6g.en.txt
# Converted 7V-dlNgMkWM.en.vtt to 7V-dlNgMkWM.en.txt
# Converted M90hQZEOMGc.en.vtt to M90hQZEOMGc.en.txt
# Converted Ig7Ux3PP4As.en.vtt to Ig7Ux3PP4As.en.txt
# Converted QsHs4XXebjw.en.vtt to QsHs4XXebjw.en.txt
# Converted juwrQVV5Vgc.en.vtt to juwrQVV5Vgc.en.txt
# Converted HSnaAtyqPQk.en.vtt to HSnaAtyqPQk.en.txt
# Converted -kBJXPJjGa0.en.vtt to -kBJXPJjGa0.en.txt
# Converted jZqcco-qDco.en.vtt to jZqcco-qDco.en.txt
# Converted YxpPqzjLnbk.en.vtt to YxpPqzjLnbk.en.txt
# Converted MsX4xLZr3zQ.en.vtt to MsX4xLZr3zQ.en.txt
# Converted MsDfIveYFnU.en.vtt to MsDfIveYFnU.en.txt
# Converted uA0kzsZv9sA.en.vtt to uA0kzsZv9sA.en.txt
# Converted fdE0K6suN8E.en.vtt to fdE0K6suN8E.en.txt
# Converted oesNSLA1JR4.en.vtt to oesNSLA1JR4.en.txt
# Converted svcYkLO8gPw.en.vtt to svcYkLO8gPw.en.txt
# Converted EQ9lceUAEuA.en.vtt to EQ9lceUAEuA.en.txt
# Converted _OC6hsPTJOU.en.vtt to _OC6hsPTJOU.en.txt
# Converted Rbv4lhuPCuY.en.vtt to Rbv4lhuPCuY.en.txt
# Converted 2otpj2xLUcE.en.vtt to 2otpj2xLUcE.en.txt
# Converted JFTXm1mD9Zw.en.vtt to JFTXm1mD9Zw.en.txt
# Converted bBHgdSu_a14.en.vtt to bBHgdSu_a14.en.txt
# Converted SjoUQRLIRKU.en.vtt to SjoUQRLIRKU.en.txt
# Converted YGEyIRKvuls.en.vtt to YGEyIRKvuls.en.txt
# Converted P4gGeZmEUqw.en.vtt to P4gGeZmEUqw.en.txt
# Converted zv26HBHwfM4.en.vtt to zv26HBHwfM4.en.txt
# Converted luNFWn-SASg.en.vtt to luNFWn-SASg.en.txt
# Converted EbzorfHBzGg.en.vtt to EbzorfHBzGg.en.txt
# Converted RXsa61QQ8_4.en.vtt to RXsa61QQ8_4.en.txt
# Converted Q5xJ7sBGZX8.en.vtt to Q5xJ7sBGZX8.en.txt
# Converted EihOXD_nVkM.en.vtt to EihOXD_nVkM.en.txt
# Converted GwnVgPZukF0.en.vtt to GwnVgPZukF0.en.txt
# Converted w1d7TDySZsI.en.vtt to w1d7TDySZsI.en.txt
# Converted 5ESlK-TNl9Q.en.vtt to 5ESlK-TNl9Q.en.txt
# Converted ldf-hqIDig8.en.vtt to ldf-hqIDig8.en.txt
# Converted f2KzTqbtLiQ.en.vtt to f2KzTqbtLiQ.en.txt
# Converted 269t4VGyulY.en.vtt to 269t4VGyulY.en.txt
# Converted XvmfvuE1Gz8.en.vtt to XvmfvuE1Gz8.en.txt
# Converted uMgWFKEIIh0.en.vtt to uMgWFKEIIh0.en.txt
# Converted snU75mjkqio.en.vtt to snU75mjkqio.en.txt
# Converted ktWWUB7vcbg.en.vtt to ktWWUB7vcbg.en.txt
# Converted 8xUEjdgYHNs.en.vtt to 8xUEjdgYHNs.en.txt
# Converted zg-81QRLOcA.en.vtt to zg-81QRLOcA.en.txt
# Converted n2ROBHVFoDA.en.vtt to n2ROBHVFoDA.en.txt
# Converted hpBMlNsyCOA.en.vtt to hpBMlNsyCOA.en.txt
# Converted XjeEw2xNiBs.en.vtt to XjeEw2xNiBs.en.txt
# Converted zX6FuY-zx-g.en.vtt to zX6FuY-zx-g.en.txt
# Converted bc0zhI8XPbM.en.vtt to bc0zhI8XPbM.en.txt
# Converted C1DzHuCHBWM.en.vtt to C1DzHuCHBWM.en.txt
# Converted iFUk9nXQQC8.en.vtt to iFUk9nXQQC8.en.txt
# Converted f5alu9CySYY.en.vtt to f5alu9CySYY.en.txt
# Converted 64bQj1X8yAg.en.vtt to 64bQj1X8yAg.en.txt
# Converted t8F9lORU9L0.en.vtt to t8F9lORU9L0.en.txt
# Converted nD2yJr2id4M.en.vtt to nD2yJr2id4M.en.txt
# Converted GWULt7iOolU.en.vtt to GWULt7iOolU.en.txt
# Converted hmptHMl6LO8.en.vtt to hmptHMl6LO8.en.txt
# Converted exXUKOAlIhM.en.vtt to exXUKOAlIhM.en.txt
# Converted fHfoAh2bhKI.en.vtt to fHfoAh2bhKI.en.txt
# Converted T0a2SfyOb3E.en.vtt to T0a2SfyOb3E.en.txt
# Converted We8sntm_4bE.en.vtt to We8sntm_4bE.en.txt
# Converted 0cOLVztzIF8.en.vtt to 0cOLVztzIF8.en.txt
# Converted hZbGO_f_znw.en.vtt to hZbGO_f_znw.en.txt
# Converted 5-6NbWLDkxI.en.vtt to 5-6NbWLDkxI.en.txt
# Converted aDS5mmZij-4.en.vtt to aDS5mmZij-4.en.txt
# Converted PqtK1GOuJt8.en.vtt to PqtK1GOuJt8.en.txt
# Converted FQ0kP3qCR1g.en.vtt to FQ0kP3qCR1g.en.txt
# Converted 7KkRF8rteL4.en.vtt to 7KkRF8rteL4.en.txt
# Converted GMfYEQBSYuU.en.vtt to GMfYEQBSYuU.en.txt
# Converted iq3WZ8jmzTg.en.vtt to iq3WZ8jmzTg.en.txt
# Converted -0ztrHj6FzA.en.vtt to -0ztrHj6FzA.en.txt
# Converted tAz-fb4TPZw.en.vtt to tAz-fb4TPZw.en.txt
# Converted v5-XdDCf2Iw.en.vtt to v5-XdDCf2Iw.en.txt
# Converted TouPkgfxtmQ.en.vtt to TouPkgfxtmQ.en.txt
# Converted Zt4rz9pp-AM.en.vtt to Zt4rz9pp-AM.en.txt
# Converted jgdCiJymay0.en.vtt to jgdCiJymay0.en.txt
# Converted O_5Tty2HLns.en.vtt to O_5Tty2HLns.en.txt
# Converted g-fE_gDXwsE.en.vtt to g-fE_gDXwsE.en.txt
# Converted -MFwXfl_SHs.en.vtt to -MFwXfl_SHs.en.txt
# Converted Ajiv4pD-6q4.en.vtt to Ajiv4pD-6q4.en.txt
# Converted 9X6oqkwAqjA.en.vtt to 9X6oqkwAqjA.en.txt
# Converted u9LbQD-40bk.en.vtt to u9LbQD-40bk.en.txt
# Converted mcrasAshiGM.en.vtt to mcrasAshiGM.en.txt
# Converted 2TXg2f9lQwI.en.vtt to 2TXg2f9lQwI.en.txt
# Converted UaxZ1N0Apao.en.vtt to UaxZ1N0Apao.en.txt
# Converted kSrmUN_vICA.en.vtt to kSrmUN_vICA.en.txt
# Converted kE7BZn3bM30.en.vtt to kE7BZn3bM30.en.txt
# Converted q4wdXrANYFk.en.vtt to q4wdXrANYFk.en.txt
# Converted DYq5bXa43cU.en.vtt to DYq5bXa43cU.en.txt
# Converted EQzUZaiPXX8.en.vtt to EQzUZaiPXX8.en.txt
# Converted stIQ-QpppbQ.en.vtt to stIQ-QpppbQ.en.txt
# Converted TOl1_W4cpc8.en.vtt to TOl1_W4cpc8.en.txt
# Converted SAdvsWx5uDk.en.vtt to SAdvsWx5uDk.en.txt
# Converted 467l6ET-CKA.en.vtt to 467l6ET-CKA.en.txt
# Converted PbYQoOAmZ5k.en.vtt to PbYQoOAmZ5k.en.txt
# Converted dq7_0TF3kzY.en.vtt to dq7_0TF3kzY.en.txt
# Converted 8uXfyodalMc.en.vtt to 8uXfyodalMc.en.txt
# Converted P1hAWxeae_I.en.vtt to P1hAWxeae_I.en.txt
# Converted DL-s2cavn1U.en.vtt to DL-s2cavn1U.en.txt
# Converted q6kNdnY2wSk.en.vtt to q6kNdnY2wSk.en.txt
# Converted zSt079dZ9I8.en.vtt to zSt079dZ9I8.en.txt
# Converted mUAIzki8GC4.en.vtt to mUAIzki8GC4.en.txt
# Converted f4UHXdNJan8.en.vtt to f4UHXdNJan8.en.txt
# Converted 9kJMFptNG1M.en.vtt to 9kJMFptNG1M.en.txt
# Converted GDHXpXiQLOo.en.vtt to GDHXpXiQLOo.en.txt
# Converted _N326-JdKgg.en.vtt to _N326-JdKgg.en.txt
# Converted Pv1khQMAWBE.en.vtt to Pv1khQMAWBE.en.txt
# Converted wxVY3Cb72e8.en.vtt to wxVY3Cb72e8.en.txt
# Converted JmqCY3SlKfU.en.vtt to JmqCY3SlKfU.en.txt
# Converted UWNBeiJGN_M.en.vtt to UWNBeiJGN_M.en.txt
# Converted pA-IvYfDcHo.en.vtt to pA-IvYfDcHo.en.txt
# Converted OlhBL5_-nx4.en.vtt to OlhBL5_-nx4.en.txt
# Converted 7j5Vab37Mpk.en.vtt to 7j5Vab37Mpk.en.txt
# Converted uLtCQrc_cRA.en.vtt to uLtCQrc_cRA.en.txt
# Converted ENDo17tI3_k.en.vtt to ENDo17tI3_k.en.txt
# Converted TtcAWlhiDzw.en.vtt to TtcAWlhiDzw.en.txt
# Converted 1EVnLgqIgs8.en.vtt to 1EVnLgqIgs8.en.txt
# Converted Pbfq3M6Ci6s.en.vtt to Pbfq3M6Ci6s.en.txt
# Converted 0TEzNDC8APE.en.vtt to 0TEzNDC8APE.en.txt
# Converted mBa2SpcpF54.en.vtt to mBa2SpcpF54.en.txt
# Converted YjzAna9QnXA.en.vtt to YjzAna9QnXA.en.txt
# Converted UfdfPNz7AB4.en.vtt to UfdfPNz7AB4.en.txt
# Converted G_Ay1iHPdSU.en.vtt to G_Ay1iHPdSU.en.txt
# Converted hqtp5_WST5M.en.vtt to hqtp5_WST5M.en.txt
# Converted lJBBFIY5q1s.en.vtt to lJBBFIY5q1s.en.txt
# Converted 0Hu3hTLQgYA.en.vtt to 0Hu3hTLQgYA.en.txt
# Converted gCmTj2xOK6E.en.vtt to gCmTj2xOK6E.en.txt
# Converted 7kqd9uqXjzs.en.vtt to 7kqd9uqXjzs.en.txt
# Converted _p11Vgv81lA.en.vtt to _p11Vgv81lA.en.txt
# Converted ZRub-LUlSAM.en.vtt to ZRub-LUlSAM.en.txt
# Converted dz7vtDKlHzU.en.vtt to dz7vtDKlHzU.en.txt
# Converted QguIE6KZ8Ps.en.vtt to QguIE6KZ8Ps.en.txt
# Converted GI14VsAaAHI.en.vtt to GI14VsAaAHI.en.txt
# Converted NZFnzllE2pc.en.vtt to NZFnzllE2pc.en.txt
# Converted e1RhKfH4zD8.en.vtt to e1RhKfH4zD8.en.txt
# Converted gobM4UGEYmU.en.vtt to gobM4UGEYmU.en.txt
# Converted aLZTHclt9OQ.en.vtt to aLZTHclt9OQ.en.txt
# Converted 0N0IrbuRstc.en.vtt to 0N0IrbuRstc.en.txt
# Converted TMvdV-EPKcM.en.vtt to TMvdV-EPKcM.en.txt
# Converted BqnxljUdl6o.en.vtt to BqnxljUdl6o.en.txt
# Converted I5nasoOaMOA.en.vtt to I5nasoOaMOA.en.txt
# Converted BrMdpvGqBII.en.vtt to BrMdpvGqBII.en.txt
# Converted TNQmjaFGYec.en.vtt to TNQmjaFGYec.en.txt
# Converted hIamjAYPW1Y.en.vtt to hIamjAYPW1Y.en.txt
# Converted opgqUnLwxIY.en.vtt to opgqUnLwxIY.en.txt
# Converted _VwYCbm1f0Y.en.vtt to _VwYCbm1f0Y.en.txt
# Converted 7FZnfEdUiUQ.en.vtt to 7FZnfEdUiUQ.en.txt
# Converted sA6Rzm5ZzAQ.en.vtt to sA6Rzm5ZzAQ.en.txt
# Converted q2OABobCQ-k.en.vtt to q2OABobCQ-k.en.txt
# Converted s-W6SO80Rp4.en.vtt to s-W6SO80Rp4.en.txt
# Converted TIBdtQBXDU4.en.vtt to TIBdtQBXDU4.en.txt
# Converted zvtjWG12x_g.en.vtt to zvtjWG12x_g.en.txt
# Converted SVY4YxO9d4s.en.vtt to SVY4YxO9d4s.en.txt
# Converted 77Okd3c2bdA.en.vtt to 77Okd3c2bdA.en.txt
# Converted TgGwDSp3zzM.en.vtt to TgGwDSp3zzM.en.txt
# Converted jrqR0B8Ljpk.en.vtt to jrqR0B8Ljpk.en.txt
# Converted aC_x9YDvURM.en.vtt to aC_x9YDvURM.en.txt
# Converted Au7jHBZizbw.en.vtt to Au7jHBZizbw.en.txt
# Converted bHgVDBTkRCg.en.vtt to bHgVDBTkRCg.en.txt
# Converted PTSKsZVlrbQ.en.vtt to PTSKsZVlrbQ.en.txt
# Converted 0UejuQCPBLo.en.vtt to 0UejuQCPBLo.en.txt
# Converted t0P7AFdvIx0.en.vtt to t0P7AFdvIx0.en.txt
# Converted aGweu-rkkt8.en.vtt to aGweu-rkkt8.en.txt
# Converted cq4kRw__CVc.en.vtt to cq4kRw__CVc.en.txt
# Converted sylE0sJoPnE.en.vtt to sylE0sJoPnE.en.txt
# Converted -mgT35daBsA.en.vtt to -mgT35daBsA.en.txt
# Converted -GYKzfbnxQI.en.vtt to -GYKzfbnxQI.en.txt
# Converted TZRVRE2ehuY.en.vtt to TZRVRE2ehuY.en.txt
# Converted V83nAO9q-ew.en.vtt to V83nAO9q-ew.en.txt
# Converted 1cR_ItbKxkM.en.vtt to 1cR_ItbKxkM.en.txt
# Converted ZpKj8LIBn5k.en.vtt to ZpKj8LIBn5k.en.txt
# Converted 3i6CNSMfVSg.en.vtt to 3i6CNSMfVSg.en.txt
# Converted uW0Sc_75ubM.en.vtt to uW0Sc_75ubM.en.txt
# Converted 0opF0Sk60fE.en.vtt to 0opF0Sk60fE.en.txt
# Converted YEUXOkOBbAU.en.vtt to YEUXOkOBbAU.en.txt
# Converted EtgjtDYo0T0.en.vtt to EtgjtDYo0T0.en.txt
# Converted zfZOo5t5c3w.en.vtt to zfZOo5t5c3w.en.txt
# Converted FC0ZkNcjGvQ.en.vtt to FC0ZkNcjGvQ.en.txt
# Converted eRvDPwGHX6w.en.vtt to eRvDPwGHX6w.en.txt
# Converted yohoVt88VO4.en.vtt to yohoVt88VO4.en.txt
# Converted CkI5Bock9Lc.en.vtt to CkI5Bock9Lc.en.txt
# Converted bEX5ocuCOLQ.en.vtt to bEX5ocuCOLQ.en.txt
# Converted 8KgCqVf-TG4.en.vtt to 8KgCqVf-TG4.en.txt
# Converted zailoFK4SE8.en.vtt to zailoFK4SE8.en.txt
# Converted ni1G30z99VU.en.vtt to ni1G30z99VU.en.txt
# Converted J9epztvyYk4.en.vtt to J9epztvyYk4.en.txt
# Converted QuaLMAerXzg.en.vtt to QuaLMAerXzg.en.txt
# Converted YyQKhvOBeLY.en.vtt to YyQKhvOBeLY.en.txt
# Converted S6XwNr1A3cU.en.vtt to S6XwNr1A3cU.en.txt
# Converted O2U96-P5Dx8.en.vtt to O2U96-P5Dx8.en.txt
# Converted 5FH6F7uB4bo.en.vtt to 5FH6F7uB4bo.en.txt
# Converted 28FJWXEISkU.en.vtt to 28FJWXEISkU.en.txt
# Converted UJ9KbVoAhJc.en.vtt to UJ9KbVoAhJc.en.txt
# Converted gIpm5TsrPU4.en.vtt to gIpm5TsrPU4.en.txt
# Converted E80X3MTTZ2o.en.vtt to E80X3MTTZ2o.en.txt
# Converted Zianj1rvFsM.en.vtt to Zianj1rvFsM.en.txt
# Converted YSTvYzjYpCo.en.vtt to YSTvYzjYpCo.en.txt
# Converted QfmjWvhgjzg.en.vtt to QfmjWvhgjzg.en.txt
# Converted EKD0g0gi2fk.en.vtt to EKD0g0gi2fk.en.txt
# Converted RtQHJi0O-Ic.en.vtt to RtQHJi0O-Ic.en.txt
# Converted qb8jjjVc6_M.en.vtt to qb8jjjVc6_M.en.txt
# Converted lg-us63185c.en.vtt to lg-us63185c.en.txt
# Converted EiaAkx3zupA.en.vtt to EiaAkx3zupA.en.txt
# Converted fNqRs-NIfDM.en.vtt to fNqRs-NIfDM.en.txt
# Converted KsT3AF8gmjg.en.vtt to KsT3AF8gmjg.en.txt
# Converted ICuEOldU4UI.en.vtt to ICuEOldU4UI.en.txt
# Converted ZoQTeeKHGoQ.en.vtt to ZoQTeeKHGoQ.en.txt
# Converted kYwrFIngy4c.en.vtt to kYwrFIngy4c.en.txt
# Converted 6svIB2qEE64.en.vtt to 6svIB2qEE64.en.txt
# Converted m53MhWQi3oI.en.vtt to m53MhWQi3oI.en.txt
# Converted HIoCaw4KAcA.en.vtt to HIoCaw4KAcA.en.txt
# Converted -aje2fKB-X4.en.vtt to -aje2fKB-X4.en.txt
# Converted 1JFaLkSTin4.en.vtt to 1JFaLkSTin4.en.txt
# Converted ATs0ODy7--8.en.vtt to ATs0ODy7--8.en.txt
# Converted 0gTQbh8_IGQ.en.vtt to 0gTQbh8_IGQ.en.txt
# Converted PAbkCVUKnmA.en.vtt to PAbkCVUKnmA.en.txt
# Converted 9fiQh4xLbcA.en.vtt to 9fiQh4xLbcA.en.txt
# Converted 502H0mcIfDY.en.vtt to 502H0mcIfDY.en.txt
# Converted 92tx1eEsSMw.en.vtt to 92tx1eEsSMw.en.txt
# Converted C3XZAVVOOqo.en.vtt to C3XZAVVOOqo.en.txt
# Converted ATQMpYAOMgU.en.vtt to ATQMpYAOMgU.en.txt
# Converted qknzGMaU81o.en.vtt to qknzGMaU81o.en.txt
# Converted X7L8tY5PQD4.en.vtt to X7L8tY5PQD4.en.txt
# Converted n9I3O45DeDM.en.vtt to n9I3O45DeDM.en.txt
# Converted Yq11m34-rt0.en.vtt to Yq11m34-rt0.en.txt
# Converted uRf2nYglwCU.en.vtt to uRf2nYglwCU.en.txt
# Converted qFOfo87YYd4.en.vtt to qFOfo87YYd4.en.txt
# Converted 0NKYLqYF9D0.en.vtt to 0NKYLqYF9D0.en.txt
# Converted EHRG_Fh-JFI.en.vtt to EHRG_Fh-JFI.en.txt
# Converted -kNe2LL4o64.en.vtt to -kNe2LL4o64.en.txt
# Converted op_o_BjgHvM.en.vtt to op_o_BjgHvM.en.txt
# Converted LwDXyhWNX18.en.vtt to LwDXyhWNX18.en.txt
# Converted oGHcB1bKLaY.en.vtt to oGHcB1bKLaY.en.txt
# Converted E3Ncoo4fg44.en.vtt to E3Ncoo4fg44.en.txt
# Converted jGcUjhmBOcA.en.vtt to jGcUjhmBOcA.en.txt
# Converted UWP5102G2Io.en.vtt to UWP5102G2Io.en.txt
# Converted ANAn60aYy7k.en.vtt to ANAn60aYy7k.en.txt
# Converted JT7J3-8UDm4.en.vtt to JT7J3-8UDm4.en.txt
# Converted 0bTKqr7zWaI.en.vtt to 0bTKqr7zWaI.en.txt
# Converted Ftnc9l1yJ9E.en.vtt to Ftnc9l1yJ9E.en.txt
# Converted 6_f6RD7xL58.en.vtt to 6_f6RD7xL58.en.txt
# Converted 1TZLzpjxo4g.en.vtt to 1TZLzpjxo4g.en.txt
# Converted 2EKLE2c9FO0.en.vtt to 2EKLE2c9FO0.en.txt
# Converted WilS8nMR5AI.en.vtt to WilS8nMR5AI.en.txt
# Converted G3IBwqilUO8.en.vtt to G3IBwqilUO8.en.txt
# Converted -xRyv9jw1Po.en.vtt to -xRyv9jw1Po.en.txt
# Converted L3cugVVja44.en.vtt to L3cugVVja44.en.txt
# Converted AtmnIhk051g.en.vtt to AtmnIhk051g.en.txt
# Converted SBk84gGjBJ0.en.vtt to SBk84gGjBJ0.en.txt
# Converted zrRzVAa-3gw.en.vtt to zrRzVAa-3gw.en.txt
# Converted zNLUWLseXBs.en.vtt to zNLUWLseXBs.en.txt
# Converted s4bNUCWe24M.en.vtt to s4bNUCWe24M.en.txt
# Converted EB3kwwPqbMI.en.vtt to EB3kwwPqbMI.en.txt
# Converted z08rrB0h_6g.en.vtt to z08rrB0h_6g.en.txt
# Converted g8vezqea0To.en.vtt to g8vezqea0To.en.txt
# Converted qnxwySfJ8y4.en.vtt to qnxwySfJ8y4.en.txt
# Converted -cvF_mKHJUM.en.vtt to -cvF_mKHJUM.en.txt
# Converted 1Bc8xEaOOtc.en.vtt to 1Bc8xEaOOtc.en.txt
# Converted k3HGp9wTB54.en.vtt to k3HGp9wTB54.en.txt
# Converted YNUh1JoVZbA.en.vtt to YNUh1JoVZbA.en.txt
# Converted BjIXbsOqv50.en.vtt to BjIXbsOqv50.en.txt
# Converted S_krIutuhzM.en.vtt to S_krIutuhzM.en.txt
# Converted fn5OawH0rp4.en.vtt to fn5OawH0rp4.en.txt
# Converted ucDOMMCYpVM.en.vtt to ucDOMMCYpVM.en.txt
# Converted zAggS9TXFlI.en.vtt to zAggS9TXFlI.en.txt
# Converted L8SFgVcDhoY.en.vtt to L8SFgVcDhoY.en.txt
# Converted 2MSOmC42Cyc.en.vtt to 2MSOmC42Cyc.en.txt
# Converted 1qoxkp2dFgM.en.vtt to 1qoxkp2dFgM.en.txt
# Converted E-BqjiALSo0.en.vtt to E-BqjiALSo0.en.txt
# Subtitles converted to text and saved in /content/drive/MyDrive/Downloads/text_subtitles

# %%
import shutil
from google.colab import files

# Path to the folder to download
folder_to_download = "/content/drive/MyDrive/Downloads/subtitles"
# Path to the output zip file
zip_path = "/content/subtitles.zip"

# Zip the folder
shutil.make_archive(zip_path.replace(".zip", ""), 'zip', folder_to_download)

# Download the zip file
files.download(zip_path)

print(f"The folder has been zipped and is ready for download: {zip_path}")
# Out:
# The folder has been zipped and is ready for download: /content/subtitles.zip
